# %% [markdown]
# ## 一个风和日丽的早上。。。

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# # Practical 7 – Iteration Control Structures in Python I
# Temasek Junior College <br>2022 JC1 H2 Computing
# ## Session Objectives
# By the end of this session, you will learn:
# 1. the use of the for loop in Python.
# 2. the use of the while loop in Python.

# %% [markdown]
# ## 7.1	Performing Iteration in Python
#
# In Python, loops are used to repeatedly execute a block of statements so long as some conditions remain true.
#
# There are two types of loops in Python:
# -	`for` loop;
# -	`while` loop.
#
# The use of loops is important to ensure that statements that need to be repeatedly executed are coded once only and not repeatedly. This reduces unnecessary code length.

# %% [markdown]
# ## 7.2	The `for` loop
#
# A `for` loop provides a way to perform actions for all items in an iterable.
#
# An iterable can be a string, a list, a range of values, a tuple, a dictionary etc.
#
# The general syntax structure of a for loop is as follows:
#
# ```python
# 	for <item> in iterable:
# 	    statement
# ```

# %%
# Exercise 1

# %%
x = input("Hello!")

# %%
x = input("Hello!")
print(x)
# Out:
# Hello!hello
# hello

# %%
def inport_thing():
    valid = False
    while valid == False:
        thing = input("Enter your requested loan in Dollars only: ")
        try:
            thing = float(thing)
            if thing<0 or thing>100_000:
                raise ValueError

        except ValueError:
            print("Please enter only non-negative numbers that are less than 100 000: ")
        except:
            print("Something went wrong, please try again: ")
        else:
            thing = float(thing)
            valid = True
            return thing

def deposit_calculation(loan):
    if loan < 25_000:
        deposit = (5/100)*loan
    elif loan > 25_000 and loan < 50_000:
        deposit = 1250 + (10/100)*(loan-25_000)
    else:
        deposit = 5000 + (25/100)*(loan-50_000)
    return deposit

loan = inport_thing()

print("Your deposit is ${}".format(deposit_calculation(loan)))
# Out:
# Enter your requested loan in Dollars only: 59000
# Your deposit is $7250.0

# %%
for i in range(0,30,3):
    print(i)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27

# %% [markdown]
# ## 7.3	The `while` loop
#
# The Python `while` loop operates on the following principle:
#
# As long as the condition remains `True`, the statement will be executed repeatedly until the condition is no longer True.
#
# The general syntax structure of a `while` loop is as follows:
#
# ```python
# 	while <condition>:
# 	    statement
# ```

# %%
while True:
    print("h")
# Out:
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# h
# ...

# %% [markdown]
# ## Mini Hackathon (30 mins)
#
#  *You are reminded to use meaningful identifiers and identifier conventions adhering to PEP 8.
#
# *You are reminded to also include the use proper commenting in your program

# %% [markdown]
# __Problem 1__
#
# Write a program to prompt the user for x positive integers, one at a time.
#
# Compute and output the sum of all x integers entered.

# %%
def inport_thing():
    valid = False
    while valid == False:
        thing = input("Please enter a positive integer ")
        try:
            thing = float(thing)
            if thing<=0 or float(thing).is_integer() == False:
                raise ValueError

        except ValueError:
            print("Please enter only positive integers: ")
        except:
            print("Something went wrong, please try again: ")
        else:
            thing = int(thing)
            valid = True
            return thing

num = int(input("How many integers? "))
total = 0

for i in range(num):
    total = total + inport_thing()

print("The sum is {}".format(total))
# Out:
# How many integers? 2
# Please enter a positive integer 9
# Please enter a positive integer 18
# The sum is 27

# %% [markdown]
# __Problem 2__
#
# Write an enhanced version of the program in __Problem 1__ to also compute and output the average of x positive integers.

# %%
def inport_thing():
    valid = False
    while valid == False:
        thing = input("Please enter a positive integer ")
        try:
            thing = float(thing)
            if thing<=0 or float(thing).is_integer() == False:
                raise ValueError

        except ValueError:
            print("Please enter only positive integers: ")
        except:
            print("Something went wrong, please try again: ")
        else:
            thing = int(thing)
            valid = True
            return thing

num = int(input("How many integers? "))
total = 0

for i in range(num):
    total = total + inport_thing()

print("The average is {}".format((total/num)))
# Out:
# How many integers? 2
# Please enter a positive integer 9
# Please enter a positive integer 18
# The average is 13.5

# %% [markdown]
# __Problem 3__
#
# Write a program to prompt the user for x positive integers, one at a time, until the user terminates with -1. Compute and output the sum of all x integers entered.

# %%
def inport_thing():
    valid = False
    while valid == False:
        thing = input("Please enter a positive integer ")
        try:
            thing = float(thing)
            if thing<-1 or float(thing).is_integer() == False:
                raise ValueError

        except ValueError:
            print("Please enter only positive integers: ")
        except:
            print("Something went wrong, please try again: ")
        else:
            thing = int(thing)
            valid = True
            return thing

total = 0
num = 0

while True:
    
    temp = inport_thing()
    
    if temp == -1:
        break 
    else:
        total = total + temp
        num = num + 1

print("The average is {}".format((total/num)))
# Out:
# Please enter a positive integer 2
# Please enter a positive integer 2
# Please enter a positive integer -1
# The average is 2.0

# %% [markdown]
# __Problem 4a__ (Tutorial 2.4 Q6 of Problem Solving and Algorithm Design 2)
#
# Write a program to prompt the user for a positive integer n, compute and output n factorial, using `for` loop.

# %%
def inport_thing():
    valid = False
    while valid == False:
        thing = input("Please enter a positive integer ")
        try:
            thing = float(thing)
            if thing<-1 or float(thing).is_integer() == False:
                raise ValueError

        except ValueError:
            print("Please enter only positive integers: ")
        except:
            print("Something went wrong, please try again: ")
        else:
            thing = int(thing)
            valid = True
            return thing

total = 0
num = 0


total = inport_thing()
total2 = 1
for i in range(1,total):
        total2 = total2 * i
        print(total2)
        

print("The factorial is {}".format((total2)))
# Out:
# Please enter a positive integer 5
# 1
# 2
# 6
# 24
# The factorial is 24

# %% [markdown]
# __Problem 4b__ (Tutorial 2.4 Q6 of Problem Solving and Algorithm Design 2)
#
# Write a program to prompt the user for a positive integer n, compute and output n factorial, using `while` loop.

# %%
def inport_thing():
    valid = False
    while valid == False:
        thing = input("Please enter a positive integer ")
        try:
            thing = float(thing)
            if thing<-1 or float(thing).is_integer() == False:
                raise ValueError

        except ValueError:
            print("Please enter only positive integers: ")
        except:
            print("Something went wrong, please try again: ")
        else:
            thing = int(thing)
            valid = True
            return thing

total = 0
num = 0


total = inport_thing()
total2 = 1
i = 1
while i < total:
        total2 = total2 * i
        print(total2)
        i +=1
        

print("The factorial is {}".format((total2)))
# Out:
# Please enter a positive integer 5
# 1
# 2
# 6
# 24
# The factorial is 24

# %% [markdown]
# __Problem 5__
#
# Create a number guessing game that will perform the following
# -	Generate at random a secret integer value from 1 to 100
# -	Allow user to make a guess
#         - If the guess is correct, congratulate the user
#         - If the guess is too small, prompt the user to guess a larger value.
#         - If the guess is too large, prompt the user to guess a smaller value.
#
# To generate a random value, think of how you can use the follow statements:
#
# ```python
# 	import random
# 	# x is the lower limit, y is the upper limit
# 	random.randint(x, y)
# ```
#
# You may search the internet on the use of the above two statements.

# %%
import random
rand = random.randint(1,100)
valid = False
imput = int(input("Guess the value: "))
while valid == False:
    if imput < rand:
        print("Guess a larger value")
    elif imput > rand:
        print("Guess a smaller value")
    else:
        print("You got it!")
        valid = True
    imput = int(input("Guess the value: "))
# Out:
# Guess the value: 69
# Guess a smaller value
# Guess the value: 50
# Guess a larger value
# Guess the value: 55
# Guess a smaller value
# Guess the value: 54
# Guess a smaller value
# Guess the value: 53
# You got it!
