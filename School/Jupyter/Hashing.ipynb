# %%
def HS(studentID):
    Hash = 0
    HashTotal = 0
    for i in range(len(studentID)): 
        HashTotal = HashTotal + ord(studentID[i])
    Hash = HashTotal % 500
    return Hash

def generate_hash_dict(inputlist):
    #generate key-value pair for all itmes in the list and store in a dictionary
    #key is the hash value and value is the student ID
    dictionary = {}
    for i in range(len(inputlist)):
        dictionary[HS(inputlist[i])] = inputlist[i]
    print(type(dictionary))
    return dictionary
    


def main():
    No = '0'
    studentIDList = [
'G1923358Q','S8744135I','S7721536G',\
'S7733010G','S8740525E','S6709440C',\
'S8671460B','S8742506Z','S8734053F',\
'S9535433B','S9634621F','S9414585G',\
'S9603708F','S9309384I','S9234153B',\
'S7847448F','S8747447H','S7713451J',\
'S9819719I','S7612861D','S8728919J',\
'S9942155B','S9914425G','S9519664D',\
'S9632366F','S9239107F','S7742882D',\
'S7622993C','S8628526D','S7620076E']
    studentIDDict = generate_hash_dict(studentIDList)
    print(studentIDDict)
    lst = [None] * 500
    for No in range(len(lst)):
        if studentIDDict.get(No) != None:

            if lst[No] == None:
                lst[No] = studentIDDict[No]
            else:
                if No % 500 != 0:
                    for i in range(No, 500):
                        
                        if lst[i] == None:
                            lst[i] = studentIDDict[No]
                            break
                else:
                    for i in range(0, 500):
                        if lst[i] == None:
                            lst[i] = studentIDDict[No]
                            break
    for i,v in enumerate(lst):
        print(i,v)

main()
# Out:
# <class 'dict'>
# {19: 'S8734053F', 24: 'S8628526D', 21: 'S7713451J', 11: 'S7733010G', 16: 'S7620076E', 17: 'S9535433B', 41: 'S8742506Z', 20: 'S9239107F', 26: 'S9414585G', 22: 'S9603708F', 28: 'S9309384I', 12: 'S9234153B', 31: 'S7847448F', 32: 'S8747447H', 36: 'S9819719I', 18: 'S7612861D', 37: 'S8728919J', 27: 'S9519664D', 25: 'S7742882D'}
# 0 None
# 1 None
# 2 None
# 3 None
# 4 None
# 5 None
# 6 None
# 7 None
# 8 None
# 9 None
# 10 None
# 11 S7733010G
# 12 S9234153B
# 13 None
# 14 None
# 15 None
# 16 S7620076E
# 17 S9535433B
# 18 S7612861D
# 19 S8734053F
# 20 S9239107F
# 21 S7713451J
# 22 S9603708F
# 23 None
# 24 S8628526D
# 25 S7742882D
# 26 S9414585G
# 27 S9519664D
# 28 S9309384I
# 29 None
# 30 None
# 31 S7847448F
# 32 S8747447H
# 33 None
# 34 None
# 35 None
# 36 S9819719I
# 37 S8728919J
# 38 None
# 39 None
# 40 None
# 41 S8742506Z
# 42 None
# 43 None
# 44 None
# 45 None
# 46 None
# 47 None
# 48 None
# 49 None
# 50 None
# 51 None
# 52 None
# 53 None
# 54 None
# 55 None
# 56 None
# ...

# %%
print
