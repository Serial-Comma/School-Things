# %%
#Task 1

class AccountHolder:

    #Constuctor

    def __init__(self):
        self.HolderName = "NAME"
        self.Address = "ADDRESS"
        self.Profession = "PROFESSION"
        self.BirthDate = "01/01/1900"
        print(f"+++ AccountHolder('{self.HolderName}') has been created")

    #Destructor

    def __del__(self):
        print(f"--- AccountHolder('{self.HolderName}') has been destroyed")
        return True

# %%
#Task 2


class AccountHolder:
# Constructor -- assign default values with default values to data members
    def __init__(self,hdName = "NAME", hdAddress = "ADDRESS", hdProfession = "PROFESSION", hdBday = "01/91/1900"):
        self.Holdername = hdName
        self.Address = hdAddress
        self.Profession = hdProfession
        self.Birthday = hdBday
        print(f"+++AccountHolder ('{self.Holdername}') has been created") # Prints the message when the object is created

    def __str__(self):
        return(f"Name: {self.Holdername}\tAddress: {self.Address}\tProfession: {self.Profession}\tBirthday: {self.Birthday}")
#Destructor
    def __del__(self):
        print(f"---AccountHolder ('{self.Holdername}') has been destroyed") # Prints the message when the object is destroyed
        return True

def main():
    print("Task_1 Class AccountHolder created successfully") # Prints the message when the program is run

#Driver
def main():
    # ah1 = AccountHolder() 
    # print(f"\n 01] ah1 ID={id(ah1)}") 
    # print(f"\n 02] ah1 attributes - Name: {ah1.Holdername}, Address: {ah1.Address}, Profession: {ah1.Profession}, Birthday: {ah1.Birthday}") 
    # print(f"\n 04] ah1 dir(ah1)- : {dir(ah1)}") 
    # print(f"\n 05] ah1.__dict__- : {ah1.__dict__}") 
    # ah1Keys = ah1.__dict__.keys() 
    # print(f"\n 06] Data type of ah1Keys: {type(ah1Keys)}")
    # ah1Fields = ah1.__dict__
    # print(f" 07] ah1 dictionary elements: {ah1Fields['Holdername']}, {ah1Fields['Address']}, {ah1Fields['Profession']}, {ah1Fields['Birthday']}")
    # print(f" 08] ah1Fields.values() - : {ah1Fields.values()}") 
    # ah1List = list(ah1Fields) #Converts the dictionary to a list
    # print(f" 09] ah1 List elements: {ah1List[0]}, {ah1List[1]}, {ah1List[2]}, {ah1List[3]}")
    # ah2 = AccountHolder
    # ah3 = ah2
    # print(f"\n 10] ah1 ID={id(ah1)}, ah2 ID = {id(ah2)}, ah3 ID = {id(ah3)}") 
    # print(f"\n 11] ah1 == ah2: {ah1 == ah2}") 
    # print(f"\n 12] ah2 == ah3: {ah2 == ah3}") 

    ah1 = AccountHolder()
    print(f"\n 01] object ah1: {ah1}")
    #Values of attributes pass from external enviroment
    ah2 = AccountHolder("John", "123 Main St.", "Teacher", "01/01/2000")
    print(f"\n 02] object ah2: {ah2}")  


main()
# Out:
# +++AccountHolder ('NAME') has been created
#
#  01] object ah1: Name: NAME	Address: ADDRESS	Profession: PROFESSION	Birthday: 01/91/1900
# +++AccountHolder ('John') has been created
#
#  02] object ah2: Name: John	Address: 123 Main St.	Profession: Teacher	Birthday: 01/01/2000
# ---AccountHolder ('NAME') has been destroyed
# ---AccountHolder ('John') has been destroyed

# %%
#Task_3.py
#Version 1.01 Date:26/07/22 Creator: Dickson Lai
# ******Module: 'AccountHolder' - Class creation ******

class AccountHolder:
    ## Constructor-assign default values to data members
    def __init__(self, hdName='Name',hdAddr='ADDRESS',
                 hdProf='PROFESSION', hdBday='01/01/1990' ):
        # Instance attribute with default values
        self.HolderName = hdName
        self.Address = hdAddr
        self.Profession = hdProf
        self.BirthDay = hdBday
        print(f'+++AccountHolder {self.HolderName} has been created!')

    ## Destructor
    def __del__(self):
        print(f'+++AccountHolder {self.HolderName} has been destroyed!')
        return True

    ##Method
    def __str__(self):
        return(f'HolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\n')



def main():
    ah1=AccountHolder() #****** object instantiation *****
    print(ah1)
    print(ah1.__str__()) #Both called __str__()


main()
# Out:
# +++AccountHolder Name has been created!
# HolderName: Name
# Address: ADDRESS
# Profession: PROFESSION
# Birthday: 01/01/1990
#
# HolderName: Name
# Address: ADDRESS
# Profession: PROFESSION
# Birthday: 01/01/1990
#
# +++AccountHolder Name has been destroyed!

# %%
#Task 4

class AccountHolder:
# Constructor -- assign default values with default values to data members
    def __init__(self,hdName = "NAME", hdAddress = "ADDRESS", hdProf = "PROFESSION", hdBday = "01/91/1900"):
        self.Holdername = hdName
        self.Address = hdAddress
        self.Profession = hdProf
        self.Birthday = hdBday
        print(f"+++AccountHolder ('{self.Holdername}') has been created") # Prints the message when the object is created

    def __str__(self):
        return(f"Name: {self.Holdername}\tAddress: {self.Address}\tProfession: {self.Profession}\tBirthday: {self.Birthday}")
#Destructor
    def __del__(self):
        print(f"---AccountHolder ('{self.Holdername}') has been destroyed") # Prints the message when the object is destroyed
        return True

    def __str__(self):
        return f"Name: {self.Holdername}\tAddress: {self.Address}\tProfession: {self.Profession}\tBirthday: {self.Birthday}"

def main():
    ah1 = AccountHolder()
    print(f"01] object ah1: {ah1}")
    ah2 = AccountHolder('WAUNG ZHEN LIN JUSTIN', '310A ANCHOVLAE ROAD, #13-31 S(541310)', 'ACCOUNTANT', '23/07/1998')   # ***** Object instantiation *****
    ah3 = AccountHolder('PAIK POH LEONG', 'BLK 502 WEST COAST DRIVE, #01-55 S(120502)', 'RETIRED', '12/04/1954')
    ah4 = AccountHolder('CLEMENT NG', 'BLK 38 DEFU LANE 10 #02-03 S(539215)', 'LECTURER', '11/05/1992')
    ah5 = AccountHolder('ALICE YONG', '', '', '')
    print(f"02] object ah2: {ah2}")
    print(f"03] object ah3: {ah3}")
    print(f"04] object ah4: {ah4}")
    print(f"05] object ah5: {ah5}")

main()
# Out:
# +++AccountHolder ('NAME') has been created
# 01] object ah1: Name: NAME	Address: ADDRESS	Profession: PROFESSION	Birthday: 01/91/1900
# +++AccountHolder ('WAUNG ZHEN LIN JUSTIN') has been created
# +++AccountHolder ('PAIK POH LEONG') has been created
# +++AccountHolder ('CLEMENT NG') has been created
# +++AccountHolder ('ALICE YONG') has been created
# 02] object ah2: Name: WAUNG ZHEN LIN JUSTIN	Address: 310A ANCHOVLAE ROAD, #13-31 S(541310)	Profession: ACCOUNTANT	Birthday: 23/07/1998
# 03] object ah3: Name: PAIK POH LEONG	Address: BLK 502 WEST COAST DRIVE, #01-55 S(120502)	Profession: RETIRED	Birthday: 12/04/1954
# 04] object ah4: Name: CLEMENT NG	Address: BLK 38 DEFU LANE 10 #02-03 S(539215)	Profession: LECTURER	Birthday: 11/05/1992
# 05] object ah5: Name: ALICE YONG	Address: 	Profession: 	Birthday:
# ---AccountHolder ('NAME') has been destroyed
# ---AccountHolder ('WAUNG ZHEN LIN JUSTIN') has been destroyed
# ---AccountHolder ('PAIK POH LEONG') has been destroyed
# ...

# %%
#Task_5.py
#Version 1.01 Date:29/07/22 Creator: Dickson Lai
# ******Module: 'AccountHolder' - Class creation ******

class AccountHolder:
    ## Constructor-assign default values to data members
    def __init__(self, hdName='Name',hdAddr='ADDRESS',
                 hdProf='PROFESSION', hdBday='01/01/1990' ):
        # Instance attribute with default values
        self.HolderName = hdName
        self.Address = hdAddr
        self.Profession = hdProf
        self.BirthDay = hdBday
        print(f'+++AccountHolder {self.HolderName} has been created!')

    ## Destructor
    def __del__(self):
        print(f'+++AccountHolder {self.HolderName} has been destroyed!')
        return True

    
    def __str__(self):
        return(f'\nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\n')



def main():
    ah1=AccountHolder() #****** object instantiation *****
    print(f'\n 01] object ah1: {ah1}')

    # * Values of attributes pass from external enviroment
    ah2=AccountHolder('Waung Shu Ling','61 KP ARANG ROAD','Accountant','23/07/1998')
    print(f'02] object ah2: {ah2}')
    
    ah1.HolderName='AISAH'
    ah1.Address='Blk 35 Mandalay Road'
    ah1.Profession='Banker'
    ah1.BirthDay='03/08/1980'
    print(f'\n 01] object ah1: {ah1}')


# ******* Driver ********
main()
# Out:
# +++AccountHolder Name has been created!
#
#  01] object ah1:
# HolderName: Name
# Address: ADDRESS
# Profession: PROFESSION
# Birthday: 01/01/1990
#
# +++AccountHolder Waung Shu Ling has been created!
# 02] object ah2:
# HolderName: Waung Shu Ling
# Address: 61 KP ARANG ROAD
# Profession: Accountant
# Birthday: 23/07/1998
#
#
#  01] object ah1:
# HolderName: AISAH
# Address: Blk 35 Mandalay Road
# Profession: Banker
# Birthday: 03/08/1980
#
# +++AccountHolder AISAH has been destroyed!
# +++AccountHolder Waung Shu Ling has been destroyed!

# %%
#Task_6.py
#Version 1.01 Date:29/07/22 Creator: Dickson Lai
# ******Module: class member visibility - Public method ******

class AccountHolder:
    ## Constructor-assign default values to data members
    def __init__(self, hdName='Name',hdAddr='ADDRESS',
                 hdProf='PROFESSION', hdBday='01/01/1990' ):
        # Instance attribute with default values
        self.HolderName = hdName
        self.Address = hdAddr
        self.Profession = hdProf
        self.BirthDay = hdBday
        print(f'+++AccountHolder {self.HolderName} has been created!')

    ## Destructor
    def __del__(self):
        print(f'+++AccountHolder {self.HolderName} has been destroyed!')
        return True

    def NameCard(self):  #Public method
        return(f'{"="*50} \
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\
        \n{"="*50}')
    
    def __str__(self):
        return(f'\nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\n')



def main():
    ah1=AccountHolder() #****** object instantiation *****
    print(f'\n 01] object ah1: {ah1}')

    # * Values of attributes pass from external enviroment
    ah2=AccountHolder('Waung Shu Ling','61 KP ARANG ROAD','Accountant','23/07/1998')
    print(f'02] object ah2: {ah2}')
    
    ah1.HolderName='AISAH'
    ah1.Address='Blk 35 Mandalay Road'
    ah1.Profession='Banker'
    ah1.BirthDay='03/08/1980'
    print(f'\n 01] object ah1: {ah1}')
    print('\n')
    print(ah1.NameCard())
    print(ah2.NameCard())


# ******* Driver ********
main()
# Out:
# +++AccountHolder Name has been created!
#
#  01] object ah1:
# HolderName: Name
# Address: ADDRESS
# Profession: PROFESSION
# Birthday: 01/01/1990
#
# +++AccountHolder Waung Shu Ling has been created!
# 02] object ah2:
# HolderName: Waung Shu Ling
# Address: 61 KP ARANG ROAD
# Profession: Accountant
# Birthday: 23/07/1998
#
#
#  01] object ah1:
# HolderName: AISAH
# Address: Blk 35 Mandalay Road
# Profession: Banker
# Birthday: 03/08/1980
#
#
#
# ...
# HolderName: AISAH
# Address: Blk 35 Mandalay Road
# Profession: Banker
# Birthday: 03/08/1980
# ...
# HolderName: Waung Shu Ling
# Address: 61 KP ARANG ROAD
# Profession: Accountant
# Birthday: 23/07/1998
# ...
# +++AccountHolder AISAH has been destroyed!
# +++AccountHolder Waung Shu Ling has been destroyed!

# %%
#Task_7.py
#Version 1.01 Date:29/07/22 Creator: Dickson Lai
# ******Module: Array of object******

class AccountHolder:
    ## Constructor-assign default values to data members
    def __init__(self, hdName='Name',hdAddr='ADDRESS',
                 hdProf='PROFESSION', hdBday='01/01/1990' ):
        # Instance attribute with default values
        self.HolderName = hdName
        self.Address = hdAddr
        self.Profession = hdProf
        self.BirthDay = hdBday
        print(f'+++AccountHolder {self.HolderName} has been created!')

    ## Destructor
    def __del__(self):
        print(f'+++AccountHolder {self.HolderName} has been destroyed!')
        return True

    def NameCard(self):  #Public method
        return(f'{"="*50} \
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\
        \n{"="*50}')
    
    def __str__(self):
        return(f'\nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\n')



def main():
    newAH=[] #Get array ready
    LENGTH=10 #Length of array
    #Creation of array of objects
    newAH=[AccountHolder() for i in range(LENGTH)]
    
    for i in range(len(newAH)):
        print(f'\t{i+1:2} {newAH[i]} {id(newAH[i])}\n')
    newAH[3].HolderName='AISAH'
    print(f'newAH[3].HolderName:{newAH[3].HolderName}')
    newAH.append(AccountHolder())

    for i in range(len(newAH)):
        print (f'\t{i+1:2} {newAH[i]} {id(newAH[i])}\n')
    for i in range(len(newAH)):
        print (f'\t{i+1:2}\n{newAH[i].NameCard()}\n')

# ******* Driver ********
main()
# Out:
# +++AccountHolder Name has been created!
# +++AccountHolder Name has been created!
# +++AccountHolder Name has been created!
# +++AccountHolder Name has been created!
# +++AccountHolder Name has been created!
# +++AccountHolder Name has been created!
# +++AccountHolder Name has been created!
# +++AccountHolder Name has been created!
# +++AccountHolder Name has been created!
# +++AccountHolder Name has been created!
# 	 1
# HolderName: Name
# Address: ADDRESS
# Profession: PROFESSION
# Birthday: 01/01/1990
#  139776021938816
#
# 	 2
# HolderName: Name
# Address: ADDRESS
# Profession: PROFESSION
# Birthday: 01/01/1990
#  139776021952256
#
# 	 3
# HolderName: Name
# Address: ADDRESS
# Profession: PROFESSION
# Birthday: 01/01/1990
#  139776021940256
#
# 	 4
# HolderName: Name
# Address: ADDRESS
# Profession: PROFESSION
# Birthday: 01/01/1990
#  139776021952112
#
# 	 5
# HolderName: Name
# Address: ADDRESS
# Profession: PROFESSION
# Birthday: 01/01/1990
#  139776021941360
#
# 	 6
# ...

# %%
## Task_8.py
## Version: 8.01  Date: 25-July-2022 Programmer: Fong KK
## ***** Module: array of objects with data READ from TEXT file accHolders.DAT *****

class AccountHolder:
   ## Constructor 
   def __init__(self, hdName = 'NAME', hdAddr = 'ADDRESS', hdProf = 'PROFESSION', hdBday = '01/01/1900'):        
   ### Instance attributes/Data members
      self.HolderName = hdName   
      self.Address    = hdAddr  
      self.Profession = hdProf   
      self.BirthDay   = hdBday  
      print(f"+++ AccountHolder ('{self.HolderName }') has been created!")
   def NameCard(self):
        return f"{'='*50}\n"\
               f"\t{self.HolderName}\n" \
               f"\t{self.Address}\n\t{self.Profession}\n"\
               f"{'='*50}"
   def __str__(self):
        return f"Name: {self.HolderName}\t" \
               f"|Address:{self.Address} \t|Profession: {self.Profession}\t "\
               f"|BirthDay: {self.BirthDay} " 
      ## Destructor
   def __del__ (self):
      print(f"--- AccountHolder ('{self.HolderName }') has been destroyed!")
      return True
def main():    
   newAH = []	# Get array ready
   sourceFileName = "accHolders.DAT"
 
   accHolderFile = open(sourceFileName, "r")
   for record in accHolderFile:
      ahFields = record.split(',')
      newAH.append(AccountHolder(ahFields[0], ahFields[1], ahFields[2], ahFields[3]))
   accHolderFile.close()
##Display all objects
   for i in range (len(newAH)):   
      print(f"\t{i+1:2} { newAH[i]} {id(newAH[i])}")  
   for i in range (len(newAH)):
      print(f"\t{i+1:2}\n { newAH[i].NameCard()}")      
# ***** Driver *****
main()
# Out:
# +++ AccountHolder ('WAUNG ZHEN LIN JUSTIN') has been created!
# +++ AccountHolder ('TAY XINYI MICHELLE') has been created!
# +++ AccountHolder ('SHERSAIN TAN') has been created!
# +++ AccountHolder ('YING WENG SENG') has been created!
# +++ AccountHolder ('TAN ZHAO YAN CHARLENE') has been created!
# +++ AccountHolder ('JANZEN KOH WEI LIANG') has been created!
# +++ AccountHolder ('MARINAH BTE MOHD YUNOS') has been created!
# +++ AccountHolder ('AFIQA NADIA BTE ZAINAL') has been created!
# +++ AccountHolder ('CHO SIQI') has been created!
# +++ AccountHolder ('KANNAN RAJ S/O RAJAMOHAN') has been created!
# 	 1 Name: WAUNG ZHEN LIN JUSTIN	|Address:111 North Bridge Road #05-46 S(179098) 	|Profession: ACCOUNTANT	 |BirthDay: 12/03/1990
#   139776156510688
# 	 2 Name: TAY XINYI MICHELLE	|Address:501 JURONG WEST STREET 51 01-263 S(640501) 	|Profession: TEACHER	 |BirthDay: 30/05/1994
#   139775675307712
# ...

# %%
#Task_9.py
#Version 1.01 Date:04/08/22 Creator: Dickson Lai
# ******Module: Add title from dictionary******
TitleTypes={
    'T1':'Mr',
    'T2':'Ms',
    'T3':'Mdm',
    'T4':'Mrs',
    'T5':'Sir',
    'T6':'Doctor',
    'TD':'TITLE'}

class AccountHolder:
    ## Constructor-assign default values to data members
    def __init__(self, hdTitl='TITLE',hdName='Name',hdAddr='ADDRESS',
                 hdProf='PROFESSION', hdBday='01/01/1990' ):
        # Instance attribute with default values
        self.Title=hdTitl
        self.HolderName = hdName
        self.Address = hdAddr
        self.Profession = hdProf
        self.BirthDay = hdBday
        print(f'+++AccountHolder {self.HolderName} has been created!')

    ## Destructor
    def __del__(self):
        print(f'+++AccountHolder {self.HolderName} has been destroyed!')
        return True

    def NameCard(self):  #Public method
        return(f'{"="*50} \
        \nHolder Title: {TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\
        \n{"="*50}')
    
    def __str__(self):
        return(f'\nHolder Title: {TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\n')


def main():
    source='accHolders-tt.DAT'
    newAH=[]
    with open(source,'r') as f:
        for record in f:
            ahFields=record.split(',')
            newAH.append(AccountHolder(ahFields[0],ahFields[1],ahFields[2],ahFields[3],ahFields[4]))
    for obj in newAH:
        print (obj)
#Driver
main()
# Out:
# +++AccountHolder WAUNG ZHEN LIN JUSTIN has been created!
# +++AccountHolder TAY XINYI MICHELLE has been created!
# +++AccountHolder SHERSAIN TAN has been created!
# +++AccountHolder YING WENG SENG has been created!
# +++AccountHolder TAN ZHAO YAN CHARLENE has been created!
# +++AccountHolder JANZEN KOH WEI LIANG has been created!
# +++AccountHolder MARINAH BTE MOHD YUNOS has been created!
# +++AccountHolder AFIQA NADIA BTE ZAINAL has been created!
# +++AccountHolder CHO SIQI has been created!
# +++AccountHolder KANNAN RAJ S/O RAJAMOHAN has been created!
#
# Holder Title: Mr
# HolderName: WAUNG ZHEN LIN JUSTIN
# Address: 111 North Bridge Road #05-46 S(179098)
# Profession: ACCOUNTANT
# Birthday: 12/03/1990
#
#
#
# Holder Title: Ms
# HolderName: TAY XINYI MICHELLE
# Address: 501 JURONG WEST STREET 51 01-263 S(640501)
# Profession: TEACHER
# Birthday: 30/05/1994
#
#
#
# Holder Title: Mdm
# HolderName: SHERSAIN TAN
# Address: 9 Raffles Pl #02-21 S(048619)
# Profession: MANAGER
# ...

# %%
#Task_9_1.py
#Version 1.01 Date:04/08/22 Creator: Dickson Lai
# ******Module: Add title from dictionary [csv]******
import csv
TitleTypes={
    'T1':'Mr',
    'T2':'Ms',
    'T3':'Mdm',
    'T4':'Mrs',
    'T5':'Sir',
    'T6':'Doctor',
    'TD':'TITLE'}

class AccountHolder:
    ## Constructor-assign default values to data members
    def __init__(self, hdTitl='TITLE',hdName='Name',hdAddr='ADDRESS',
                 hdProf='PROFESSION', hdBday='01/01/1990' ):
        # Instance attribute with default values
        self.Title=hdTitl
        self.HolderName = hdName
        self.Address = hdAddr
        self.Profession = hdProf
        self.BirthDay = hdBday
        print(f'+++AccountHolder {self.HolderName} has been created!')

    ## Destructor
    def __del__(self):
        print(f'+++AccountHolder {self.HolderName} has been destroyed!')
        return True

    def NameCard(self):  #Public method
        return(f'{"="*50} \
        \nHolder Title: {TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\
        \n{"="*50}')
    
    def __str__(self):
        return(f'\nHolder Title: {TitleTypes[self.Title]}\
                \nHolderName: {self.HolderName}\
                \nAddress: {self.Address}\
                \nProfession: {self.Profession}\
                \nBirthday: {self.BirthDay}\n')
    



def main():
    source='./dataSource/accHolders-tt.csv'
    newAH=[]
    with open(source,'r') as f:
        reader=csv.reader(f)
        header=next(reader)
        for ahFields in reader:
            print(ahFields)
            newAH.append(AccountHolder(ahFields[0],ahFields[1],ahFields[2],ahFields[3],ahFields[4]))
    for obj in newAH:
        print (obj)
#Driver
main()
# Out:
# ['T1', 'WAUNG ZHEN LIN JUSTIN', '111 North Bridge Road #05-46 S(179098)', 'ACCOUNTANT', '12/3/1990']
# +++AccountHolder WAUNG ZHEN LIN JUSTIN has been created!
# ['T2', 'TAY XINYI MICHELLE', '501 JURONG WEST STREET 51 01-263 S(640501)', 'TEACHER', '30/5/1994']
# +++AccountHolder TAY XINYI MICHELLE has been created!
# ['T3', 'SHERSAIN TAN', '9 Raffles Pl #02-21 S(048619)', 'MANAGER', '4/8/1972']
# +++AccountHolder SHERSAIN TAN has been created!
# ['T4', 'YING WENG SENG', '304 Orchard Rd #03-39/43 S(238863)', 'SALES AGENT', '22/11/1997']
# +++AccountHolder YING WENG SENG has been created!
# ['T5', 'TAN ZHAO YAN CHARLENE', '101 Kitchener Road #03-18 S(208511)', 'SHOP OWNER', '21/6/1979']
# +++AccountHolder TAN ZHAO YAN CHARLENE has been created!
# ['T3', 'JANZEN KOH WEI LIANG', '61 Tai Seng Ave #05-01 S(534167)', 'CLERK', '22/1/1977']
# +++AccountHolder JANZEN KOH WEI LIANG has been created!
# ...

# %%
#Task_10.py
#Version 1.01 Date:04/08/22 Creator: Dickson Lai
# ******Module: implement Display()******
TitleTypes={
    'T1':'Mr',
    'T2':'Ms',
    'T3':'Mdm',
    'T4':'Mrs',
    'T5':'Sir',
    'T6':'Doctor',
    'TD':'TITLE'}

class AccountHolder:
    ## Constructor-assign default values to data members
    def __init__(self, hdTitl='TITLE',hdName='Name',hdAddr='ADDRESS',
                 hdProf='PROFESSION', hdBday='01/01/1990' ):
        # Instance attribute with default values
        self.Title=hdTitl
        self.HolderName = hdName
        self.Address = hdAddr
        self.Profession = hdProf
        self.BirthDay = hdBday
        print(f'+++AccountHolder {self.HolderName} has been created!')

    ## Destructor
    def __del__(self):
        print(f'+++AccountHolder {self.HolderName} has been destroyed!')
        return True

    def NameCard(self):  #Public method
        return(f'{"="*50} \
        \nHolder Title: {TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\
        \n{"="*50}')
    
    def __str__(self):
        return(f'\nHolder Title: {TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\n')

    def Display(self):
        print(f'{"Account holder record ":24}\
            \n{"-" *70 }\
            \n{"Title":<10}:{TitleTypes[self.Title]:<30}Date of birth:{self.BirthDay}\
            \n{"Name":<10}:{self.HolderName}\
            \n{"Profession":<10}:{self.Profession}\
            \n{"Address":<10}:{self.Address}\
        ')
        return ''

  

def main():
    source='accHolders-tt.DAT'
    newAH=[]
    with open(source,'r') as f:
        for record in f:
            ahFields=record.split(',')
            newAH.append(AccountHolder(ahFields[0],ahFields[1],ahFields[2],ahFields[3],ahFields[4]))
    for obj in newAH:
        obj.Display()
#Driver
main()
# Out:
# +++AccountHolder WAUNG ZHEN LIN JUSTIN has been created!
# +++AccountHolder TAY XINYI MICHELLE has been created!
# +++AccountHolder SHERSAIN TAN has been created!
# +++AccountHolder YING WENG SENG has been created!
# +++AccountHolder TAN ZHAO YAN CHARLENE has been created!
# +++AccountHolder JANZEN KOH WEI LIANG has been created!
# +++AccountHolder MARINAH BTE MOHD YUNOS has been created!
# +++AccountHolder AFIQA NADIA BTE ZAINAL has been created!
# +++AccountHolder CHO SIQI has been created!
# +++AccountHolder KANNAN RAJ S/O RAJAMOHAN has been created!
# Account holder record
# ----------------------------------------------------------------------
# Title     :Mr                            Date of birth:12/03/1990
#
# Name      :WAUNG ZHEN LIN JUSTIN
# Profession:ACCOUNTANT
# Address   :111 North Bridge Road #05-46 S(179098)
# Account holder record
# ----------------------------------------------------------------------
# ...

# %%
#Task_9_1.py
#Version 1.01 Date:04/08/22 Creator: Dickson Lai
# ******Module: Add title from dictionary [csv]******
import csv
TitleTypes={
    'T1':'Mr',
    'T2':'Ms',
    'T3':'Mdm',
    'T4':'Mrs',
    'T5':'Sir',
    'T6':'Doctor',
    'TD':'TITLE'}

class AccountHolder:
    ## Constructor-assign default values to data members
    def __init__(self, hdTitl='TITLE',hdName='Name',hdAddr='ADDRESS',
                 hdProf='PROFESSION', hdBday='01/01/1990' ):
        # Instance attribute with default values
        self.Title=hdTitl
        self.HolderName = hdName
        self.Address = hdAddr
        self.Profession = hdProf
        self.BirthDay = hdBday
        print(f'+++AccountHolder {self.HolderName} has been created!')

    ## Destructor
    def __del__(self):
        print(f'+++AccountHolder {self.HolderName} has been destroyed!')
        return True

    def NameCard(self):  #Public method
        return(f'{"="*50} \
        \nHolder Title: {TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\
        \n{"="*50}')
    
    def __str__(self):
        return(f'\nHolder Title: {TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\n')

    def Display(self):
        print(f'{"Account holder record ":24}\
            \n{"-" *70 }\
            \n{"Title":<10}:{TitleTypes[self.Title]:<30}Date of birth:{self.BirthDay}\
            \n{"Name":<10}:{self.HolderName}\
            \n{"Profession":<10}:{self.Profession}\
            \n{"Address":<10}:{self.Address}\
        ')
        return ''



def main():
    source='./dataSource/accHolders-tt.csv'
    newAH=[]
    with open(source,'r') as f:
        reader=csv.reader(f)
        header=next(reader)
        for ahFields in reader:
            print(ahFields)
            newAH.append(AccountHolder(ahFields[0],ahFields[1],ahFields[2],ahFields[3],ahFields[4]))
    for i in range(len(newAH)):
        newAH[i].Display()
#Driver
main()
# Out:
# ['T1', 'WAUNG ZHEN LIN JUSTIN', '111 North Bridge Road #05-46 S(179098)', 'ACCOUNTANT', '12/3/1990']
# +++AccountHolder WAUNG ZHEN LIN JUSTIN has been created!
# ['T2', 'TAY XINYI MICHELLE', '501 JURONG WEST STREET 51 01-263 S(640501)', 'TEACHER', '30/5/1994']
# +++AccountHolder TAY XINYI MICHELLE has been created!
# ['T3', 'SHERSAIN TAN', '9 Raffles Pl #02-21 S(048619)', 'MANAGER', '4/8/1972']
# +++AccountHolder SHERSAIN TAN has been created!
# ['T4', 'YING WENG SENG', '304 Orchard Rd #03-39/43 S(238863)', 'SALES AGENT', '22/11/1997']
# +++AccountHolder YING WENG SENG has been created!
# ['T5', 'TAN ZHAO YAN CHARLENE', '101 Kitchener Road #03-18 S(208511)', 'SHOP OWNER', '21/6/1979']
# +++AccountHolder TAN ZHAO YAN CHARLENE has been created!
# ['T3', 'JANZEN KOH WEI LIANG', '61 Tai Seng Ave #05-01 S(534167)', 'CLERK', '22/1/1977']
# +++AccountHolder JANZEN KOH WEI LIANG has been created!
# ...

# %%
#Task_11.py
#Version 1.01 Date:04/08/22 Creator: Dickson Lai
# ******Module: constant names******
#constant section
#default values for objects in class AH
HD_TITLE='TITLE'
HD_NAME='NAME'
HD_ADDRESS='ADDRESS'
HD_PROFESSION='PROFESSION'
HD_BIRTHDAY='01/01/1990'

TitleTypes={
    'T1':'Mr',
    'T2':'Ms',
    'T3':'Mdm',
    'T4':'Mrs',
    'T5':'Sir',
    'T6':'Doctor',
    'TD':'TITLE'}

class AccountHolder:
    ## Constructor-assign default values to data members
    def __init__(self, hdTitl=HD_TITLE,hdName=HD_NAME,hdAddr=HD_ADDRESS,
                 hdProf=HD_PROFESSION, hdBday=HD_BIRTHDAY ):
        # Instance attribute with default values
        self.Title=hdTitl
        self.HolderName = hdName
        self.Address = hdAddr
        self.Profession = hdProf
        self.BirthDay = hdBday
        print(f'+++AccountHolder {self.HolderName} has been created!')

    ## Destructor
    def __del__(self):
        print(f'+++AccountHolder {self.HolderName} has been destroyed!')
        return True

    def NameCard(self):  #Public method
        return(f'{"="*50} \
        \nHolder Title: {TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\
        \n{"="*50}')
    
    def __str__(self):
        return(f'\nHolder Title: {TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\n')

    def Display(self):
        print(f'{"Account holder record ":24}\
            \n{"-" *70 }\
            \n{"Title":<10}:{TitleTypes[self.Title]:<30}Date of birth:{self.BirthDay}\
            \n{"Name":<10}:{self.HolderName}\
            \n{"Profession":<10}:{self.Profession}\
            \n{"Address":<10}:{self.Address}\
        ')
        return ''

  

def main():
    source='accHolders-tt.DAT'
    newAH=[]
    with open(source,'r') as f:
        for record in f:
            ahFields=record.split(',')
            newAH.append(AccountHolder(ahFields[0],ahFields[1],ahFields[2],ahFields[3],ahFields[4]))
    for obj in newAH:
        obj.Display()
#Driver
main()
# Out:
# +++AccountHolder WAUNG ZHEN LIN JUSTIN has been created!
# +++AccountHolder TAY XINYI MICHELLE has been created!
# +++AccountHolder SHERSAIN TAN has been created!
# +++AccountHolder YING WENG SENG has been created!
# +++AccountHolder TAN ZHAO YAN CHARLENE has been created!
# +++AccountHolder JANZEN KOH WEI LIANG has been created!
# +++AccountHolder MARINAH BTE MOHD YUNOS has been created!
# +++AccountHolder AFIQA NADIA BTE ZAINAL has been created!
# +++AccountHolder CHO SIQI has been created!
# +++AccountHolder KANNAN RAJ S/O RAJAMOHAN has been created!
# Account holder record
# ----------------------------------------------------------------------
# Title     :Mr                            Date of birth:12/03/1990
#
# Name      :WAUNG ZHEN LIN JUSTIN
# Profession:ACCOUNTANT
# Address   :111 North Bridge Road #05-46 S(179098)
# Account holder record
# ----------------------------------------------------------------------
# ...

# %%
#Task_12.py
#Version 1.01 Date:04/08/22 Creator: Dickson Lai
# ******Module: input constant names from other module******

#default values for objects in class AH
from dataSource import aC

class AccountHolder:
    ## Constructor-assign default values to data members
    def __init__(self, hdTitl=aC.HD_TITLE,hdName=aC.HD_NAME,hdAddr=aC.HD_ADDRESS,
                 hdProf=aC.HD_PROFESSION, hdBday=aC.HD_BIRTHDAY ):
        # Instance attribute with default values
        self.Title=hdTitl
        self.HolderName = hdName
        self.Address = hdAddr
        self.Profession = hdProf
        self.BirthDay = hdBday
        print(f'+++AccountHolder {self.HolderName} has been created!')

    ## Destructor
    def __del__(self):
        print(f'+++AccountHolder {self.HolderName} has been destroyed!')
        return True

    def NameCard(self):  #Public method
        return(f'{"="*50} \
        \nHolder Title: {aC.TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\
        \n{"="*50}')
    
    def __str__(self):
        return(f'\nHolder Title: {aC.TitleTypes[self.Title]}\
        \nHolderName: {self.HolderName}\
        \nAddress: {self.Address}\
        \nProfession: {self.Profession}\
        \nBirthday: {self.BirthDay}\n')

    def Display(self):
        print(f'{"Account holder record ":24}\
            \n{"-" *70 }\
            \n{"Title":<10}:{aC.TitleTypes[self.Title]:<30}Date of birth:{self.BirthDay}\
            \n{"Name":<10}:{self.HolderName}\
            \n{"Profession":<10}:{self.Profession}\
            \n{"Address":<10}:{self.Address}\
        ')
        return ''

  

def main():
    source='accHolders-tt.DAT'
    newAH=[]
    with open(source,'r') as f:
        for record in f:
            ahFields=record.split(',')
            newAH.append(AccountHolder(ahFields[0],ahFields[1],ahFields[2],ahFields[3],ahFields[4]))
    for obj in newAH:
        obj.Display()
#Driver
main()
# Out:
# +++AccountHolder WAUNG ZHEN LIN JUSTIN has been created!
# +++AccountHolder TAY XINYI MICHELLE has been created!
# +++AccountHolder SHERSAIN TAN has been created!
# +++AccountHolder YING WENG SENG has been created!
# +++AccountHolder TAN ZHAO YAN CHARLENE has been created!
# +++AccountHolder JANZEN KOH WEI LIANG has been created!
# +++AccountHolder MARINAH BTE MOHD YUNOS has been created!
# +++AccountHolder AFIQA NADIA BTE ZAINAL has been created!
# +++AccountHolder CHO SIQI has been created!
# +++AccountHolder KANNAN RAJ S/O RAJAMOHAN has been created!
# Account holder record
# ----------------------------------------------------------------------
# Title     :Mr                            Date of birth:12/03/1990
#
# Name      :WAUNG ZHEN LIN JUSTIN
# Profession:ACCOUNTANT
# Address   :111 North Bridge Road #05-46 S(179098)
# Account holder record
# ----------------------------------------------------------------------
# ...

# %%
## Task_13.py
## Version: 13.01  Date: 28-July-2022 Programmer: Fong KK
## ***** Module: Demonstration of the behaviour of private attribute type *****
import csv
##Constant section
from dataSource import aC
class AccountHolder:
   ## Constructor 
   def __init__(self, hdTilt=aC.HD_TITLE, hdName=aC.HD_NAME, \
                hdAddr=aC.HD_ADDRESS, hdProf=aC.HD_PROFESSION,\
                hdBday=aC.HD_BIRTHDAY):
      ### Instance attributes/Data members
      self.__Title    = hdTilt            ##Private
      self.HolderName = hdName  ##Public 
      self.Address    = hdAddr  ##Public
      self.Profession = hdProf  ##Public 
      self.BirthDay   = hdBday  ##Public
   def NameCard(self):
        return f"{'='*50}\n"\
               f"\t{self.__Title}. {self.HolderName}\n"\
               f"\t{self.Address}\n\t{self.Profession}\n"\
               f"{'='*50}"
   def __str__(self):
        return f"Title: {self.__Title}\t" \
               f"|Name: {self.HolderName}\t" \
               f"|Address: {self.Address}\t|Profession: {self.Profession}\t"\
               f"|BirthDay: {self.BirthDay}" 
      ## Destructor
   def __del__ (self):
      return True
   def Display(self): # Use of Dictionary for TitleTypes
      print(f"{'Account holder record ':24}\n"
             f"{'-' * 70}\n"
             f"{'Title: ' + aC.TitleTypes[self.__Title]:34}"
             f"{'Date of birth: ' + self.BirthDay:>34}\n"
             f"{'Name: ' + self.HolderName:30}\n"
             f"{'Profession: ' + self.Profession:22}\n"
             f"{'Address: ' + self.Address:18}\n"
             f"{'-' * 70}")
      return ''
def main():
   newAH = []	# Get array ready
   sourceFileName = "accHolders.csv"
   ahCsvFile = open(sourceFileName, 'r', newline='', encoding='UTF8')
   ahRecords = csv.reader(ahCsvFile)
   next(ahRecords) #skipping header
   # Iterate over each row in the csv using reader object
   for ahrow in ahRecords:
       newAH.append(AccountHolder(ahrow[0], ahrow[1],\
                    ahrow[2], ahrow[3], ahrow[4]))
   ahCsvFile.close()
   print('1]', newAH[2])
   newAH[2].HolderName = 'Chang Pin Thong'
   print('2]', newAH[2])
   #print('3]', newAH[2].__Title)
   newAH[2].__Title = 't4'
   print('4]', newAH[2])
     
# ***** Driver *****
main()
# Out:
# 1] Title: T3	|Name: SHERSAIN TAN	|Address: 9 Raffles Pl #02-21 S(048619)	|Profession: MANAGER	|BirthDay: 4/8/1972
# 2] Title: T3	|Name: Chang Pin Thong	|Address: 9 Raffles Pl #02-21 S(048619)	|Profession: MANAGER	|BirthDay: 4/8/1972
# 4] Title: T3	|Name: Chang Pin Thong	|Address: 9 Raffles Pl #02-21 S(048619)	|Profession: MANAGER	|BirthDay: 4/8/1972

# %%
## Task_14.py
## Version: 13.01  Date: 28-July-2022 Programmer: Fong KK
## ***** Module: Demonstration of the behaviour of private attribute type *****
import csv
##Constant section
from dataSource import aC

##Validation check requirements for Title
TITLE_LENGTH=2
TITLE_1ST_CHAR='T'
TITLE_2ND_RANGE='0123456789'

class AccountHolder:
   ## Constructor 
   def __init__(self, hdTilt=aC.HD_TITLE, hdName=aC.HD_NAME, \
                hdAddr=aC.HD_ADDRESS, hdProf=aC.HD_PROFESSION,\
                hdBday=aC.HD_BIRTHDAY):
      ### Instance attributes/Data members
      self.__Title    = aC.HD_TITLE #Private, set default value
      if hdTilt != aC.HD_TITLE:
         self.setTitle(hdTilt)
      
      self.HolderName = hdName  ##Public 
      self.Address    = hdAddr  ##Public
      self.Profession = hdProf  ##Public 
      self.BirthDay   = hdBday  ##Public

   #----- Accessor (Getter) Method
   def getTitle(self):
      return self.__Title
   #----- Mutator (Setter) Method
   def setTitle(self,newTitle):
      validFlag= True
     
      if self.is_Title_valid(newTitle)==True:
         self.__Title=newTitle
      else:
         validFlag=False
         return validFlag
      
   def is_Title_valid(self,Title): ##validation check fore title'
      validFlag=True
      if len(Title)!=TITLE_LENGTH:
         validFlag=False
         print(f"Length of Title must be 2!")
      elif Title[0]!=TITLE_1ST_CHAR:
         validFlag=False
         print(f'The first character must be T!')
      elif not (Title[1] in TITLE_2ND_RANGE):
         validFlag=False
         print(f'The second character must be one of 0 to 9!')
      return validFlag
      
   def NameCard(self):
        return f"{'='*50}\n"\
               f"\t{self.__Title}. {self.HolderName}\n"\
               f"\t{self.Address}\n\t{self.Profession}\n"\
               f"{'='*50}"
   def __str__(self):
        return f"Title: {self.__Title}\t" \
               f"|Name: {self.HolderName}\t" \
               f"|Address: {self.Address}\t|Profession: {self.Profession}\t"\
               f"|BirthDay: {self.BirthDay}" 
      ## Destructor
   def __del__ (self):
      return True
   def Display(self): # Use of Dictionary for TitleTypes
      print(f"{'Account holder record ':24}\n"
             f"{'-' * 70}\n"
             f"{'Title: ' + aC.TitleTypes[self.__Title]:34}"
             f"{'Date of birth: ' + self.BirthDay:>34}\n"
             f"{'Name: ' + self.HolderName:30}\n"
             f"{'Profession: ' + self.Profession:22}\n"
             f"{'Address: ' + self.Address:18}\n"
             f"{'-' * 70}")
      return ''
def main():
   newAH = []	# Get array ready
   sourceFileName = "dataSource/accHolders-tt.csv"
   ahCsvFile = open(sourceFileName, 'r', newline='', encoding='UTF8')
   ahRecords = csv.reader(ahCsvFile)
   next(ahRecords) #skipping header
   # Iterate over each row in the csv using reader object
   for ahrow in ahRecords:
       newAH.append(AccountHolder(ahrow[0], ahrow[1],\
                    ahrow[2], ahrow[3], ahrow[4]))
   ahCsvFile.close()
   print('1]', newAH[2])
   newAH[2].setTitle  ('T4')
   print('2]', newAH[2].getTitle())
   newAH[2].setTitle('s')
   print('3]', newAH[2].getTitle())
   newAH[2].setTitle('TT2')
   print('4]', newAH[2].getTitle())
   newAH[2].setTitle('Tb')
   print('5]', newAH[2].getTitle())
   newAH[2].setTitle('t9')
   print('6]', newAH[2].getTitle())
     
# ***** Driver *****
main()
# Out:
# 1] Title: T3	|Name: SHERSAIN TAN	|Address: 9 Raffles Pl #02-21 S(048619)	|Profession: MANAGER	|BirthDay: 4/8/1972
# 2] T4
# Length of Title must be 2!
# 3] T4
# Length of Title must be 2!
# 4] T4
# The second character must be one of 0 to 9!
# 5] T4
# The first character must be T!
# 6] T4

# %%
## Task_15.py
## Version: 15.01  Date: 28-July-2022 Programmer: Fong KK
## ***** Module: Getters and Setters for all private attributes  *****
## and validation checks
import datetime
import csv
##Constant section
from dataSource import aC
### Validation check requirements for Title
TITLE_LENGTH          = 2
TITLE_1ST_CHAR        = 'T'
TITLE_2ND_RANGE       = '0123456789'
NAME_LENGTH_MIN       = 3
NAME_LENGTH_MAX       = 66
ADDRESS_LENGTH_MIN    = 20
ADDRESS_LENGTH_MAX    = 66
PROFESSION_LENGTH_MIN = 3
PROFESSION_LENGTH_MAX = 40
class AccountHolder:
   ## Constructor 
   def __init__(self, hdTilt=aC.HD_TITLE, hdName=aC.HD_NAME, \
                hdAddr=aC.HD_ADDRESS, hdProf=aC.HD_PROFESSION,\
                hdBday=aC.HD_BIRTHDAY):
      ### Instance attributes/Data members
      self.__Title = hdTilt             #Private, set default value
      if hdTilt != aC.HD_TITLE:
         self.setTitle(hdTilt)
      self.__HolderName = hdName        #Private, set default value
      if hdName != aC.HD_NAME:
         self.setHolderName(hdName)
      self.__Address = hdAddr           #Private, set default value
      if hdAddr != aC.HD_ADDRESS:
         self.setAddress(hdAddr)
      self.__Profession = hdProf        #Private, set default value
      if hdProf != aC.HD_PROFESSION:
         self.setProfession(hdProf)
      self.__BirthDay = hdBday          #Private, set default value
      if hdBday != aC.HD_BIRTHDAY:
         self.setBirthday(hdBday)        
         
   #---- Accessor (Getter) methodS
   def getTitle(self):
      return self.__Title      
   def getHolderName(self):
      return self.__HolderName
   def getAddress(self):
      return self.__Address
   def getProfession(self):
      return self.__Profession
   def getBirthday(self):
      return self.__Birthday   
   #---- Mutator (Setter) methods
   def setTitle(self, newTitle):
      validFlag = True
      if self.checkTitle(newTitle)== True:
         self.__Title = newTitle
      else:
         validFlag = False
      return validFlag     
   def setHolderName(self, newHolderName):
      validFlag = True
      if self.checkLength('Holder name', newHolderName,\
              NAME_LENGTH_MIN, NAME_LENGTH_MAX)== True:
         self.__HolderName = newHolderName
      else:
         validFlag = False
      return validFlag
   def setAddress(self, newAddress):
      validFlag = True
      if self.checkLength('Address', newAddress, \
              ADDRESS_LENGTH_MIN, ADDRESS_LENGTH_MAX)== True:
         self.__Address = newAddress
      else:
         validFlag = False
      return validFlag
   def setProfession(self, newProfession):
      validFlag = True
      if self.checkLength('Profession', newProfession,\
              PROFESSION_LENGTH_MIN, PROFESSION_LENGTH_MAX)== True:
         self.__Profession = newProfession
      else:
         validFlag = False
      return validFlag
   def setBirthday(self, newBirthday):
      validFlag = True
      if self.checkDate(newBirthday)== True:
         self.__Birthday = newBirthday
      else:
         validFlag = False
      return validFlag  
   def checkTitle(self, Title): #Validation checks for __Title
      validFlag = True
      if len(Title) != TITLE_LENGTH:            ##Length check
         validFlag = False
         print(f"Length of Title must be 2!")
      elif Title[0] != TITLE_1ST_CHAR:          ##Format check
         validFlag = False
         print(f"Error! First character of Title must be T!")
      elif not ( Title[1] in TITLE_2ND_RANGE):  ##Format check
         validFlag = False
         print(f"Error! Second character of Title must be one of 0 to 9!")         
      return validFlag         
   def checkLength(self, attribureName, newItem, LENGTH_MIN, LENGTH_MAX):
      validFlag = True
      if (len(newItem)< LENGTH_MIN or len(newItem)> LENGTH_MAX):
         print(f"Error! Length of {attribureName} is between \
{LENGTH_MIN} and {LENGTH_MAX}.")
         validFlag = False
      return validFlag  
   def checkDate(self, newDate):
##       print(newDate, type(newDate))
       validFlag = True
       newday = newDate.split('/')
       day = int(newday[0])
       month = int(newday[1])
       year = int(newday[2])
     #checks the range of year input
       try:
         h = None
         h == datetime.datetime(year, month, day)
         validFlag = True
       except ValueError:
         print("Error! Invalid date!")
         validFlag = False
         return validFlag
   def leapYear(self, y):
       validFlag = True
       if (y % 4) == 0:  
           if (y % 100) == 0:  
               if (y % 400) == 0:  
                   validFlag = True #Leap  
               else:  
                   validFlag = False #not Leap  
           else:  
               validFlag = True #Leap  
       else:  
           validFlag = False #not Leap
       return validFlag
   def NameCard(self):
        return f"{'='*50}\n"\
               f"\t{self.__Title}. {self.__HolderName}\n"\
               f"\t{self.__Address}\n\t{self.__Profession}\n"\
               f"{'='*50}"
   def __str__(self):
        return f"Title: {self.__Title}\t" \
               f"|Name: {self.__HolderName}\t" \
               f"|Address: {self.__Address}\t|Profession: {self.__Profession}\t"\
               f"|BirthDay: {self.__BirthDay}" 
      ## Destructor
   def __del__ (self):
      return True
   def Display(self): # Use of Dictionary for TitleTypes
      print(f"{'Account holder record ':24}\n"
             f"{'-' * 70}\n"
             f"{'Title: ' + aC.TitleTypes[self.__Title]:34}"
             f"{'Date of birth: ' + self.__BirthDay:>34}\n"
             f"{'Name: ' + self.__HolderName:30}\n"
             f"{'Profession: ' + self.__Profession:22}\n"
             f"{'Address: ' + self.__Address:18}\n"
             f"{'-' * 70}")
      return ''

def main():
   newAH = []	# Get array ready
   sourceFileName = "./accHolders.csv"
   ahCsvFile = open(sourceFileName, 'r', newline='', encoding='UTF8')
   ahRecords = csv.reader(ahCsvFile)
   next(ahRecords) #skipping header
   # Iterate over each row in the csv using reader object
   for ahrow in ahRecords:
       newAH.append(AccountHolder(ahrow[0], ahrow[1],\
                    ahrow[2], ahrow[3], ahrow[4]))
   ahCsvFile.close()
   print('1]', newAH[2])
   newAH[2].setTitle('T4')   
   print('2]', newAH[2].getTitle())
   newAH[2].setTitle('s')   
   print('3]', newAH[2].getTitle())
   newAH[2].setTitle('TT2')   
   print('4]', newAH[2].getTitle())   
   newAH[2].setTitle('Tb')   
   print('5]', newAH[2].getTitle())
   newAH[2].setTitle('t9')   
   print('6]', newAH[2].getTitle())
   print('7]', newAH[2])
   ahAny = AccountHolder()
   print('8]', ahAny)
##***** Driver *****
main()
# Out:
# 1] Title: T3	|Name: SHERSAIN TAN	|Address: 9 Raffles Pl #02-21 S(048619)	|Profession: MANAGER	|BirthDay: 4/8/1972
# 2] T4
# Length of Title must be 2!
# 3] T4
# Length of Title must be 2!
# 4] T4
# Error! Second character of Title must be one of 0 to 9!
# 5] T4
# Error! First character of Title must be T!
# 6] T4
# 7] Title: T4	|Name: SHERSAIN TAN	|Address: 9 Raffles Pl #02-21 S(048619)	|Profession: MANAGER	|BirthDay: 4/8/1972
# 8] Title: TITLE	|Name: NAME	|Address: ADDRESS	|Profession: PROFESSION	|BirthDay: 01/01/1990
