# %%
class Node:
    def __init__(self, data = None, left = None, right = None):
        self.data = data
        self.left = left
        self.right = right
        
    def __str__(self):
        return f"{self.data} (L: {self.left.data if self.left else '-'}, R: {self.right.data if self.right else '-'})"

# %%
class BinaryTree:
    def __init__(self, root = None):
        '''
            Constructor
        '''
        self.root = root
        
    def print_tree(self):
        '''
        print tree from root
        '''
        self._print_tree(self.root)
        
    def _print_tree(self, node_list):
        '''
        For internal use
        print tree from node list
        '''
        if not isinstance(note_list, list):
            node_list = [node_list]
        if node_list == []:
            retunn
        # convert node_list to a list if it is not
        next_layer=[]
        
        # Stop recursion if the list is empty
        while node_list:
            cur_node = node_list.pop(0)
            print(cur_node.data, end = ' ')
            if cur_node.left:
                next_layer.append(cur_node.left)
            if cur_node.right:
                next_layer.append(cur_node.right)

        print()
        sself._print_tree(next_layer)
        # define a list to collect node in next layer
        next_layer = []
        
        # Iterate through node list to print them out and put their child nodes into next_layer

        # print new line after processing a layer

        
        # process the next layer

# %%
# Test
n4 = Node("D")
n5 = Node("E")
n6 = Node("F")

n2 = Node("B", n4, n5)
n3 = Node("C", None, n6)
n1 = Node("A", n2, n3)

tree = BinaryTree(n1)

tree.print_tree()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/kenspoems/Documents/School-Things/School/2023/Binary Search Tree.ipynb Cell 3 in <cell line: 12>()
#       <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> n1 = Node("A", n2, n3)
#      <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> tree = BinaryTree(n1)
# ---> <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> tree.print_tree()
#
# /home/kenspoems/Documents/School-Things/School/2023/Binary Search Tree.ipynb Cell 3 in BinaryTree.print_tree(self)
#       <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> def print_tree(self):
#       <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a>     '''
#      <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     print tree from root
#      <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     '''
# ---> <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>     self._print_tree(self.root)
#
# /home/kenspoems/Documents/School-Things/School/2023/Binary Search Tree.ipynb Cell 3 in BinaryTree._print_tree(self, node_list)
#      <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> def _print_tree(self, node_list):
#      <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a>     '''
#      <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=15'>16</a>     For internal use
#      <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a>     print tree from node list
#      <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>     '''
# ---> <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a>     if not isinstance(note_list, list):
#      <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a>         node_list = [node_list]
#      <a href='vscode-notebook-cell:/home/kenspoems/Documents/School-Things/School/2023/Binary%20Search%20Tree.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a>     if node_list == []:
#
# NameError: name 'note_list' is not defined

# %%
class BinarySearchTree(BinaryTree):
    
    def visit_node(self, node):
        # print out the data of node
        print(node.data, end = ' ')
        
    def inorder(self):
        '''
        perform inorder traversal from the root
        '''
        self._inorder(self, root)
        
    def _inorder(self, node):
        '''
        For internal use
        perform inorder traversal from the subtree starting with node
        '''
        # if the node is None, print appropriate msg and return
        
     
        # traverse left subtree
        
        # visit node itself
        
        # traverse right subtree
        
            
    def add(self, value):
        '''
        Adds a node containing data to the tree
        '''
           if self.root == None:
            self.root = Node(value)
        else:
            self._add(self.root, value)
        
        # if BST is empty, add the node with value as root

        # otherwise, add the node to the tree starting with root

            
    def _add(self, node, value):
        '''
        For internal use
        adds a node to the subtree starting with node
        '''
        # Adds value to left subtree if value < node.data

        if value < node.data:
            if node.left == None:
                node.left = Node(value)
            else:
                self._add(node.left, value)
                
        # Adds value to right subtree if value > node.data
        
        
        # Otherwise, data already exist in the BST, just return
        
        
    def find(self, value):
        '''
        Returns the node with data if data is found in tree, None if otherwise
        '''
        # if tree is empty, print appropriate msg and return None
        
        # Otherwise, use _find to start finding from root
        

        
    def _find(self, node, value):
        '''
        Internal use only
        Returns the node with data if data is found in subtree starting with node, None if otherwise
        '''
        # if node does not exist, return None

        # if value matches the data in current node, return current node

        # if value is less than data in current node, continue finding in left subtree

        # Otherwise, find in right subtree

# %% [markdown]
# Try creating the following tree
#
# ```
#        6
#      /   \
#     2      7
#      \      \
#       3      8
# ```

# %%
# Test
bst = BinarySearchTree()
bst.add(6)
# Continue adding the rest of the nodes

print("Result of finding 5: ", bst.find(5))
print("Result of finding 6")
